# %% [markdown]
# Análisis exploratorio del dataset Titanic
# Práctica final del curso de análisis de datos con Python
# Profesor: Gerardo Mathus
# Intrucciones: Lee cuidadosamente cada pregunta y escribe el código de Python necesario para contestar cada una.
# Deberás contestar el examen en un Jupyter Notebook y, al terminar, deberás subirlo a un nuevo repositorio de
# github que contenga únicamente los datos a utilizar (ver liga de abajo) y el Jupyter Notebook con tus respuestas
# Nota: Todas las visualizaciones deberán hacerse con seaborn .

# %% [markdown]
# ### 1. Importa los datos
# Los datos los puedes descargar de esta liga (https://drive.google.com/file/d/1Ru9l2gfDIyOjJnaor17dOPUGii5SK4mJ/view?
# usp=sharing)
#
# Enlace corto: http://tiny.cc/cn9idz (http://tiny.cc/cn9idz)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('datos/titanic.csv')

# %% [markdown]
# ### 2. Observa las primeras filas de los datos

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ### 3. ¿Cuántas filas y columnas tiene el dataset?

# %%
print("El data frame tiene {} columnas y {} filas".format(len(df.columns),len(df.index)))
# Out:
# El data frame tiene 12 columnas y 891 filas

# %% [markdown]
# ### 4. ¿Qué columnas tiene el dataset?

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# ### 5. Contesta las siguientes preguntas:

# %% [markdown]
# a) ¿Cuántas variables son de tipo flotante?
# b) ¿Cuántas variables son de tipo entero?
# c) ¿Cuántas variables son de tipo objeto (categóricas)?

# %%
df.dtypes.value_counts()
# Out:
# int64      5
# object     5
# float64    2
# dtype: int64

# %% [markdown]
# d) ¿Qué columnas y tienen objetos en nulo o faltantes?

# %%
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# #### 6. Obten un resumen de estadisticos del dataset para contestar las siguientes preguntas:
# a) ¿Cuál era la edad promedio de los pasajeros del Titanic?
#
# b) ¿De cuánto era el `fare` promedio?
#
# c) ¿Cuántos pasajeros sobrevivieron?

# %%
print("a) Edad promedio de los pasajeros en el Titanic:",df.Age.mean())
print("b) El fare promedio:",df.Fare.mean())
print("c) Los sobrevivientes del Titanic fueron:",df.Survived.sum())
# Out:
# a) Edad promedio de los pasajeros en el Titanic: 29.69911764705882
# b) El fare promedio: 32.204207968574636
# c) Los sobrevivientes del Titanic fueron: 342

# %% [markdown]
# ---

# %% [markdown]
# ### Visualizaciones

# %% [markdown]
# ### 7. Visualización para valores faltantes
# #### Una buena forma visual de observar valores faltantes en columnas es mediante un mapa de calor. Utiliza la función heatmap de seaborn con cmap='flag' para graficar valores faltantes en cada columna
# #### ¿Qué puedes concluir de tu mapa de calor?

# %%
mat_corr = df.corr()
plt.figure(figsize=(12,8))
sns.heatmap(mat_corr, cmap="flag")

# %% [markdown]
# ### 8. Grafica la matriz de correlación con la función heatmap de seaborn y los argumentos cmap='YlGnBu' y annot=True . Posteriormente describe qué hace cada uno de estos argumentos.
#
# ¿Qué puedes concluir del mapa de calor de la matriz de correlación?

# %%
plt.figure(figsize=(12,8))
sns.heatmap(mat_corr,cmap="YlGnBu",annot=True)

# %% [markdown]
# ---

# %% [markdown]
# ## Exploración de la variable survived
# #### La variable survived indica si un pasajero subrevivió la tragedia del Titanic o no.
# #### * 0: No sobrevivió
# #### * 1: Sí sobrevivió

# %% [markdown]
# ### 9. Haz una gráfica de barras que muestre la cantidad de pasajeros que sobreviveron y que no sobreviveron. Utiliza la paleta 'Set1'

# %%
plt.figure(figsize=(12,8))
sns.countplot(df.Survived,palette="Set1")

# %% [markdown]
# ### 10. Imprime el número exacto de pasajeros que sobreviveron y que no sobreviveron

# %%
survived=df.Survived.sum()
not_survived=(len(df.index)-survived)
print("Survived:",survived)
print("Not survived:",not_survived)
# Out:
# Survived: 342
# Not survived: 549

# %% [markdown]
# #### 11. Haz una gráfica de barras de los pasajeros que sobreviveron y que no sobreviveron introducieron una tercera variable Sex . Utiliza la paleta 'Set2' .
# #### Deberás tener 4 barras: 2 barras (male, female) para 'no sobrevivó' y 2 barras (male, female) para 'sobrevivó

# %%
plt.figure(figsize=(12,8))
sns.countplot(df.Survived,hue=df.Sex, palette="Set2")

# %% [markdown]
# ### 12. Haz una gráfica de barras de los pasajeros que sobreviveron y que no sobreviveron introducieron una tercera variable Pclass . Utiliza la paleta 'Set2' .
# #### La variable Pclass indica el estatus socioeconómico del pasajero:
# #### 1 Upper (alta)
# #### 2 Middle (media)
# #### 3 Lower (baja)

# %%
plt.figure(figsize=(12,8))
sns.countplot(df.Survived,hue=df.Pclass, palette="Set2")

# %% [markdown]
# ### 13. Haz una gráfica de barras del número de la variable SibSp utilizando la paleta'Set3'.
# ### La variable SibSp indica la cantida de hermanos del pasajero, y si tenía o no esposo o esposa.

# %%
plt.figure(figsize=(12,8))
sns.countplot(df.Survived,hue=df.SibSp, palette="Set3")

# %% [markdown]
# ### 14. Haz lo mismo para la bariable Parch .
# ### Esta variable indica el número de padres o madres e hijos que viajaban con el pasajero.

# %%
plt.figure(figsize=(12,8))
sns.countplot(df.Survived,hue=df.Parch, palette="Set3")

# %% [markdown]
# ### 15. Haz una gráfica de barras que muestre la cantidad de pasajeros que embarcaron en C (Cherbourg), Q (Queenstown) y S (Southampton). Utiliza la paleta que quieras

# %%
plt.figure(figsize=(12,8))
sns.countplot(df.Embarked, palette="RdPu")

# %% [markdown]
# ### 16. Ejecuta el siguiente código y anota tus observaciones

# %%
sns.pairplot(data=df, hue ='Survived', diag_kind='hist', height= 3, aspect=0.7,palette='bwr')
# Out:
# C:\Users\adpli\AppData\Roaming\Python\Python37\site-packages\numpy\lib\histograms.py:829: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# C:\Users\adpli\AppData\Roaming\Python\Python37\site-packages\numpy\lib\histograms.py:830: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %% [markdown]
# ### 17. Haz una gráfica de dispersión con un ajuste lineal, y después vuelve a realizar la misma gráfica pero ahora utilizando los parámetros logistic=True y y_jitter=0.3 .Posteriormente describe para qué sirven estos parámetros

# %%
sns.lmplot(x='Fare', y='Age', hue="Pclass", data=df)

# %%
sns.lmplot(x='Fare', y='Age', hue="Pclass", logistic=True, y_jitter=0.3,data=df)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-39-f39adc36b097> in <module>
# ----> 1 sns.lmplot(x='Fare', y='Age', hue="Pclass", logistic=True, y_jitter=0.3,data=df)
#
# ~\AppData\Roaming\Python\Python37\site-packages\seaborn\regression.py in lmplot(x, y, data, hue, col, row, palette, col_wrap, height, aspect, markers, sharex, sharey, hue_order, col_order, row_order, legend, legend_out, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, x_jitter, y_jitter, scatter_kws, line_kws, size)
#     587         scatter_kws=scatter_kws, line_kws=line_kws,
#     588         )
# --> 589     facets.map_dataframe(regplot, x, y, **regplot_kws)
#     590
#     591     # Add a legend
#
# ~\AppData\Roaming\Python\Python37\site-packages\seaborn\axisgrid.py in map_dataframe(self, func, *args, **kwargs)
#     818
#     819             # Draw the plot
# --> 820             self._facet_plot(func, ax, args, kwargs)
#     821
#     822         # Finalize the annotations and layout
#
# ~\AppData\Roaming\Python\Python37\site-packages\seaborn\axisgrid.py in _facet_plot(self, func, ax, plot_args, plot_kwargs)
#     836
#     837         # Draw the plot
# --> 838         func(*plot_args, **plot_kwargs)
#     839
#     840         # Sort out the supporting information
#
# ~\AppData\Roaming\Python\Python37\site-packages\seaborn\regression.py in regplot(x, y, data, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, dropna, x_jitter, y_jitter, label, color, marker, scatter_kws, line_kws, ax)
#     787     scatter_kws["marker"] = marker
#     788     line_kws = {} if line_kws is None else copy.copy(line_kws)
# --> 789     plotter.plot(ax, scatter_kws, line_kws)
#     790     return ax
#     791
#
# ~\AppData\Roaming\Python\Python37\site-packages\seaborn\regression.py in plot(self, ax, scatter_kws, line_kws)
#     342             self.scatterplot(ax, scatter_kws)
#     343         if self.fit_reg:
# --> 344             self.lineplot(ax, line_kws)
#     345
#     346         # Label the axes
#
# ~\AppData\Roaming\Python\Python37\site-packages\seaborn\regression.py in lineplot(self, ax, kws)
#     387
#     388         # Fit the regression model
# --> 389         grid, yhat, err_bands = self.fit_regression(ax)
#     390
#     391         # Get set default aesthetics
#
# ~\AppData\Roaming\Python\Python37\site-packages\seaborn\regression.py in fit_regression(self, ax, x_range, grid)
#     193             yhat, yhat_boots = self.fit_poly(grid, self.order)
#     194         elif self.logistic:
# --> 195             from statsmodels.genmod.generalized_linear_model import GLM
#     196             from statsmodels.genmod.families import Binomial
#     197             yhat, yhat_boots = self.fit_statsmodels(grid, GLM,
#
# ModuleNotFoundError: No module named 'statsmodels'

# %% [markdown]
# ### 18. Crea un histograma de la variable Age utilizando 10, 20,30,40 y 50 cubetas (bins)

# %%
plt.figure(figsize=(12,8))
sns.distplot(df.Fare, bins=10)

# %%
plt.figure(figsize=(12,8))
sns.distplot(df.Fare,bins=20)

# %%
plt.figure(figsize=(12,8))
sns.distplot(df.Fare,bins=30)

# %%
plt.figure(figsize=(12,8))
sns.distplot(df.Fare,bins=40)

# %%
plt.figure(figsize=(12,8))
sns.distplot(df.Fare,bins=50)

# %% [markdown]
# ### 19. Crea un histograma de la variable Fare . Deberás utilizar la función dropna() para elminar valores nulos. Utiliza el color 'darkred' y experimenta con el número de cubetas hasta que estes satisfecha.

# %%
plt.figure(figsize=(12,8))
sns.distplot(df.Fare,bins=25, color="darkred")

# %% [markdown]
# ### 20. Crea un boxplot de Pclass contra Age utilizando la paleta 'plasma' y contesta las siguientes preguntas:
# ### Sin tomar en cuenta outliers:

# %% [markdown]
# #### 1. En la clase 1, ¿más o menos cuál edad mediana (cuartil 50) de los parajeros?
# #### 2. En la clase 2, ¿más o menos cuál es la edad máxima de los pasajeros?
# #### 3. En la clase 3, ¿más o menos cuál es la edad en el primer cuartil de los pasajeros? ¿Tus hallazgos coinciden con lo que da la función describe() de pandas ?

# %%
plt.figure(figsize=(12,8))
sns.boxplot(x="Pclass", y="Age", data=df, palette="plasma")

# %%
### 1.- Clase 1, edad media: 38 años
### 2.- Clase 2, máxima edad: 35 años outliers 70
### 3.- Clase 3, entre 18 y 25
df_class1 = df[df.Pclass == 1]
df_class2 = df[df.Pclass == 2]
df_class3 = df[df.Pclass == 3]
df_class1.describe()
# si coincide
# Out:
#        PassengerId    Survived  Pclass         Age       SibSp       Parch  \
# count   216.000000  216.000000   216.0  186.000000  216.000000  216.000000
# mean    461.597222    0.629630     1.0   38.233441    0.416667    0.356481
# std     246.737616    0.484026     0.0   14.802856    0.611898    0.693997
# min       2.000000    0.000000     1.0    0.920000    0.000000    0.000000
# 25%     270.750000    0.000000     1.0   27.000000    0.000000    0.000000
# 50%     472.000000    1.000000     1.0   37.000000    0.000000    0.000000
# 75%     670.500000    1.000000     1.0   49.000000    1.000000    0.000000
# max     890.000000    1.000000     1.0   80.000000    3.000000    4.000000
#
#              Fare
# count  216.000000
# mean    84.154687
# std     78.380373
# min      0.000000
# 25%     30.923950
# 50%     60.287500
# 75%     93.500000
# max    512.329200

# %%
df_class2.describe()
# Out:
#        PassengerId    Survived  Pclass         Age       SibSp       Parch  \
# count   184.000000  184.000000   184.0  173.000000  184.000000  184.000000
# mean    445.956522    0.472826     2.0   29.877630    0.402174    0.380435
# std     250.852161    0.500623     0.0   14.001077    0.601633    0.690963
# min      10.000000    0.000000     2.0    0.670000    0.000000    0.000000
# 25%     234.500000    0.000000     2.0   23.000000    0.000000    0.000000
# 50%     435.500000    0.000000     2.0   29.000000    0.000000    0.000000
# 75%     668.000000    1.000000     2.0   36.000000    1.000000    1.000000
# max     887.000000    1.000000     2.0   70.000000    3.000000    3.000000
#
#              Fare
# count  184.000000
# mean    20.662183
# std     13.417399
# min      0.000000
# 25%     13.000000
# 50%     14.250000
# 75%     26.000000
# max     73.500000

# %%
df_class3.describe()
# Out:
#        PassengerId    Survived  Pclass         Age       SibSp       Parch  \
# count   491.000000  491.000000   491.0  355.000000  491.000000  491.000000
# mean    439.154786    0.242363     3.0   25.140620    0.615071    0.393075
# std     264.441453    0.428949     0.0   12.495398    1.374883    0.888861
# min       1.000000    0.000000     3.0    0.420000    0.000000    0.000000
# 25%     200.000000    0.000000     3.0   18.000000    0.000000    0.000000
# 50%     432.000000    0.000000     3.0   24.000000    0.000000    0.000000
# 75%     666.500000    0.000000     3.0   32.000000    1.000000    0.000000
# max     891.000000    1.000000     3.0   74.000000    8.000000    6.000000
#
#              Fare
# count  491.000000
# mean    13.675550
# std     11.778142
# min      0.000000
# 25%      7.750000
# 50%      8.050000
# 75%     15.500000
# max     69.550000

# %% [markdown]
# ### 21. Haz un boxplot de la variable Fare para detectar/visualizar outliers. Utiliza la paleta Blues

# %%
plt.figure(figsize=(12,8))
sns.boxplot(df.Fare, palette="Blues")

# %% [markdown]
# ### 22. Haz un boxplot de la variable Age para detectar/visualizar outliers. Utiliza la paleta Blues

# %%
plt.figure(figsize=(12,8))
sns.boxplot(df.Age, palette="Blues")
